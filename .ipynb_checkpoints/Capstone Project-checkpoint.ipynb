# %%
import pandas as pd                       # Imported libraries and tables
import matplotlib.pyplot as plt
import seaborn as sns 
employees = pd.read_csv("employees.csv")
products = pd.read_csv("products.csv")
sunday = pd.read_csv("sunday.csv")

# %%
employees.info()                          # Data types for the employee table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Sales Team Lead  5 non-null      object
#  1   PayGrade         5 non-null      object
#  2   Region           5 non-null      object
#  3   EmpID            5 non-null      object
#  4   IsFound          5 non-null      bool
# dtypes: bool(1), object(4)
# memory usage: 293.0+ bytes

# %%
employees.head()                          # First 5 rows of employees table
# Out:
#     Sales Team Lead PayGrade Region   EmpID  IsFound
# 0       Evans, Gina      C12     NW  EMP244     True
# 1     Lawson, Harry      C11     NW  EMP256     True
# 2    Bachmann, Jane      C13     NW  EMP234     True
# 3  Clement, Beverly      C14     SW  EMP267     True
# 4      Allen, Maude      C12     SW  EMP290     True

# %%
employees.shape                           # Employee table is 5 rows by 5 columns
# Out:
# (5, 5)

# %%
employees.nunique()                       # Number of unique values in each column
# Out:
# Sales Team Lead    5
# PayGrade           4
# Region             2
# EmpID              5
# IsFound            1
# dtype: int64

# %%
sunday.info()                              # Data types for the sunday table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 104 entries, 0 to 103
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Week0+        104 non-null    int64
#  1   Week1+        104 non-null    int64
#  2   Date          104 non-null    object
#  3   Sales Period  104 non-null    int64
#  4   Sales Year    104 non-null    int64
#  5   Quarter       104 non-null    int64
# dtypes: int64(5), object(1)
# memory usage: 5.0+ KB

# %%
sunday.head()                              # First 5 rows of the sunday table
# Out:
#    Week0+  Week1+        Date  Sales Period  Sales Year  Quarter
# 0       0       1  12/30/2018             1        2019        1
# 1       1       2    1/6/2019             1        2019        1
# 2       2       3   1/13/2019             1        2019        1
# 3       3       4   1/20/2019             1        2019        1
# 4       4       5   1/27/2019             2        2019        1

# %%
sunday.shape                               # Sunday table is 104 rows by 6 columnshow
# Out:
# (104, 6)

# %%
sunday.nunique()                           # Number of unique values in each column
# Out:
# Week0+           52
# Week1+           52
# Date            104
# Sales Period     13
# Sales Year        2
# Quarter           4
# dtype: int64

# %%
products.info()                            # Data types for the products table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   PROD_CODE              8 non-null      object
#  1   PROD_NAME              8 non-null      object
#  2   URL                    8 non-null      object
#  3   link                   8 non-null      object
#  4   Manufacturer           8 non-null      object
#  5   Extended Service Plan  8 non-null      object
#  6   Warranty Price         8 non-null      int64
#  7   2019Q1                 8 non-null      int64
#  8   2019Q2                 8 non-null      int64
#  9   2019Q3                 8 non-null      int64
#  10  2019Q4                 8 non-null      int64
#  11  2020Q1                 8 non-null      int64
#  12  2020Q2                 8 non-null      int64
#  13  2020Q3                 8 non-null      int64
#  14  2020Q4                 8 non-null      int64
# ...

# %%
products.head()                            # First 5 rows for the products table
# Out:
#   PROD_CODE                   PROD_NAME  \
# 0  PROD_006      ZT2000 Zero Turn Mower
# 1  PROD_005                   UV34 Gas
# 2  PROD_004  CT1021 Sub-Compact Tractor
# 3  PROD_007       S70 Skid Steer Loader
# 4  PROD_002                       CUV82
#
#                                                  URL  \
# 0  https://www.bobcat.com/mowers/zero-turn-mowers...
# 1  https://www.bobcat.com/utility-products/utv/UV...
# 2  https://www.bobcat.com/tractors/models/ct1021/...
# 3  https://www.bobcat.com/loaders/skid-steer-load...
# 4  https://www.cat.com/en_US/products/new/equipme...
#
#                          link Manufacturer Extended Service Plan  \
# 0      ZT2000 Zero Turn Mower       Bobcat               ESP_006
# 1                   UV34 Gas        Bobcat               ESP_005
# 2  CT1021 Sub-Compact Tractor       Bobcat               ESP_004
# 3       S70 Skid Steer Loader       Bobcat               ESP_007
# 4                       CUV82          Cat               ESP_002
#
# ...

# %%
products.shape                             # The products table is 8 rows by 15 columns
# Out:
# (8, 15)

# %%
products.nunique()                         # The number of unique values in each column
# Out:
# PROD_CODE                8
# PROD_NAME                8
# URL                      6
# link                     8
# Manufacturer             3
# Extended Service Plan    8
# Warranty Price           4
# 2019Q1                   8
# 2019Q2                   8
# 2019Q3                   8
# 2019Q4                   8
# 2020Q1                   8
# 2020Q2                   8
# 2020Q3                   8
# 2020Q4                   8
# dtype: int64

# %%
pd.concat([employees,products], axis=0)    # Concatenated the employees and products tables
# Out:
#     Sales Team Lead PayGrade Region   EmpID IsFound PROD_CODE  \
# 0       Evans, Gina      C12     NW  EMP244    True       NaN
# 1     Lawson, Harry      C11     NW  EMP256    True       NaN
# 2    Bachmann, Jane      C13     NW  EMP234    True       NaN
# 3  Clement, Beverly      C14     SW  EMP267    True       NaN
# 4      Allen, Maude      C12     SW  EMP290    True       NaN
# 0               NaN      NaN    NaN     NaN     NaN  PROD_006
# 1               NaN      NaN    NaN     NaN     NaN  PROD_005
# 2               NaN      NaN    NaN     NaN     NaN  PROD_004
# 3               NaN      NaN    NaN     NaN     NaN  PROD_007
# 4               NaN      NaN    NaN     NaN     NaN  PROD_002
# 5               NaN      NaN    NaN     NaN     NaN  PROD_001
# 6               NaN      NaN    NaN     NaN     NaN  PROD_008
# 7               NaN      NaN    NaN     NaN     NaN  PROD_003
#
#                     PROD_NAME  \
# 0                         NaN
# 1                         NaN
# ...

# %%
pd.concat([employees, sunday, products], axis=1)    # Concatenated the employees, sunday, and products tables
# Out:
#       Sales Team Lead PayGrade Region   EmpID IsFound  Week0+  Week1+  \
# 0         Evans, Gina      C12     NW  EMP244    True       0       1
# 1       Lawson, Harry      C11     NW  EMP256    True       1       2
# 2      Bachmann, Jane      C13     NW  EMP234    True       2       3
# 3    Clement, Beverly      C14     SW  EMP267    True       3       4
# 4        Allen, Maude      C12     SW  EMP290    True       4       5
# ..                ...      ...    ...     ...     ...     ...     ...
# 99                NaN      NaN    NaN     NaN     NaN      47      48
# 100               NaN      NaN    NaN     NaN     NaN      48      49
# 101               NaN      NaN    NaN     NaN     NaN      49      50
# 102               NaN      NaN    NaN     NaN     NaN      50      51
# 103               NaN      NaN    NaN     NaN     NaN      51      52
#
#            Date  Sales Period  Sales Year  ...  Extended Service Plan  \
# ...
